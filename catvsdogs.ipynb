# %% [markdown]
# # Convolutional Neural Networks: Architectural Analysis on Cats vs Dogs Dataset
#
# ## Context and Motivation
# This assignment explores convolutional neural networks as architectural components rather than black-box models.
# The goal is to analyze how convolutional layers introduce inductive bias and how architectural decisions affect learning performance.
#
# We use a binary image classification task (cats vs dogs) to compare a non-convolutional baseline against a convolutional neural network designed from scratch.

# %% [markdown]
# ### Dataset Loading

# %%
import kagglehub
import os

path = kagglehub.dataset_download("yashdogra/cats-and-dogs")
print(path)

# %%
for root, dirs, files in os.walk(path):
    print(root)
    break
